# %%
import numpy as np
import pandas as pd

# %%
data_feature=pd.read_csv("C:\\Users\\ASUS\\Desktop\\DATA_SCIENCE_FOLDER\\Data_Set.csv\\Features data set.csv")

# %%
data_sales=pd.read_csv("C:\\Users\\ASUS\\Desktop\\DATA_SCIENCE_FOLDER\\Data_Set.csv\\sales data-set.csv")

# %%
data_stores=pd.read_csv("C:\\Users\\ASUS\\Desktop\\DATA_SCIENCE_FOLDER\\Data_Set.csv\\stores data-set.csv")

# %%
len(data_feature)
# Out:
# 8190

# %%
len(data_sales)
# Out:
# 421570

# %%
len(data_stores)
# Out:
# 45

# %% [markdown]
# # Data understanding/exploration/pre-processing for Data_features

# %%
data_feature.head(150)
# Out:
#      Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0        1    5/2/2010        42.31       2.572        NaN        NaN
# 1        1   12/2/2010        38.51       2.548        NaN        NaN
# 2        1  19/02/2010        39.93       2.514        NaN        NaN
# 3        1  26/02/2010        46.63       2.561        NaN        NaN
# 4        1    5/3/2010        46.50       2.625        NaN        NaN
# 5        1   12/3/2010        57.79       2.667        NaN        NaN
# 6        1  19/03/2010        54.58       2.720        NaN        NaN
# 7        1  26/03/2010        51.45       2.732        NaN        NaN
# 8        1    2/4/2010        62.27       2.719        NaN        NaN
# 9        1    9/4/2010        65.86       2.770        NaN        NaN
# 10       1  16/04/2010        66.32       2.808        NaN        NaN
# 11       1  23/04/2010        64.84       2.795        NaN        NaN
# ...

# %%
data_feature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
# Store           8190 non-null int64
# Date            8190 non-null object
# Temperature     8190 non-null float64
# Fuel_Price      8190 non-null float64
# MarkDown1       4032 non-null float64
# MarkDown2       2921 non-null float64
# MarkDown3       3613 non-null float64
# MarkDown4       3464 non-null float64
# MarkDown5       4050 non-null float64
# CPI             7605 non-null float64
# Unemployment    7605 non-null float64
# IsHoliday       8190 non-null bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 711.9+ KB

# %%
data_feature.describe()
# Out:
#              Store  Temperature   Fuel_Price      MarkDown1      MarkDown2  \
# count  8190.000000  8190.000000  8190.000000    4032.000000    2921.000000
# mean     23.000000    59.356198     3.405992    7032.371786    3384.176594
# std      12.987966    18.678607     0.431337    9262.747448    8793.583016
# min       1.000000    -7.290000     2.472000   -2781.450000    -265.760000
# 25%      12.000000    45.902500     3.041000    1577.532500      68.880000
# 50%      23.000000    60.710000     3.513000    4743.580000     364.570000
# 75%      34.000000    73.880000     3.743000    8923.310000    2153.350000
# max      45.000000   101.950000     4.468000  103184.980000  104519.540000
#
#            MarkDown3     MarkDown4      MarkDown5          CPI  Unemployment
# count    3613.000000   3464.000000    4050.000000  7605.000000   7605.000000
# mean     1760.100180   3292.935886    4132.216422   172.460809      7.826821
# ...

# %%
#checking if any column has negetive data or not(mainly fuel price and unemployement as they are not supposed to be negetive)
(data_feature<0).any().any()
np.sum((data_feature['CPI']<0).values.flatten())
np.sum((data_feature['Fuel_Price']<0).values.flatten())
# Out:
# 0

# %%
# data_markdown=data_feature[['MarkDown1','MarkDown2','MarkDown3','MarkDown4']].copy()
# filling null value

data_feature.update(data_feature.fillna(0))

# %%
data_feature.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1    5/2/2010        42.31       2.572        0.0        0.0
# 1      1   12/2/2010        38.51       2.548        0.0        0.0
# 2      1  19/02/2010        39.93       2.514        0.0        0.0
# 3      1  26/02/2010        46.63       2.561        0.0        0.0
# 4      1    5/3/2010        46.50       2.625        0.0        0.0
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        0.0        0.0        0.0  211.096358         8.106      False
# 1        0.0        0.0        0.0  211.242170         8.106       True
# 2        0.0        0.0        0.0  211.289143         8.106      False
# 3        0.0        0.0        0.0  211.319643         8.106      False
# 4        0.0        0.0        0.0  211.350143         8.106      False

# %% [markdown]
# # Data understanding/exploration/pre-processing for Data_Sales

# %%
data_sales.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1    5/2/2010      24924.50      False
# 1      1     1   12/2/2010      46039.49       True
# 2      1     1  19/02/2010      41595.55      False
# 3      1     1  26/02/2010      19403.54      False
# 4      1     1    5/3/2010      21827.90      False

# %%
data_sales.describe()
# Out:
#                Store           Dept   Weekly_Sales
# count  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123
# std        12.785297      30.492054   22711.183519
# min         1.000000       1.000000   -4988.940000
# 25%        11.000000      18.000000    2079.650000
# 50%        22.000000      37.000000    7612.030000
# 75%        33.000000      74.000000   20205.852500
# max        45.000000      99.000000  693099.360000

# %%
data_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
# Store           421570 non-null int64
# Dept            421570 non-null int64
# Date            421570 non-null object
# Weekly_Sales    421570 non-null float64
# IsHoliday       421570 non-null bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %%
data_sales.isnull().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# dtype: int64

# %%
# check if there is any negetive value in weekly_sales
(data_sales["Weekly_Sales"]<0).values.any()
count_neg=np.sum((data_sales["Weekly_Sales"]<0).values.ravel())
count_neg
# Out:
# 1285

# %%
count=0
for i in data_sales['Weekly_Sales'].values.flatten():
    
    
    if i<0:
        count=count+1

        
print (count)
# Out:
# 1285

# %%
percent_neg=(count_neg/len(data_sales))*100
percent_neg
# Out:
# 0.30481296107408024

# %%
''' so to fill the negative value we have 3 options 
                1.keep all the values as null
                2.fill it by avg value
                3.fill it by backward or forward value
                
            which one will you choose and why?
                '''
# Out:
# ' so to fill the negative value we have 3 options \n                1.keep all the values as null\n                2.fill it by avg value\n                3.fill it by backward or forward value\n                \n            which one will you choose and why?\n                '

# %%
# convert all the values to zero
data_sales['Weekly_Sales']=data_sales['Weekly_Sales'].mask(data_sales['Weekly_Sales']<0)

# %%
(data_sales['Weekly_Sales']<0).any().any()
# Out:
# False

# %%
#  Task 2.fill it by avg value

# %%
#  Task 3. fill it by backward and forward filling

# %% [markdown]
# # Data understanding/exploration/pre-processing for Data_stores

# %%
data_stores.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
set(data_stores["Type"])
# Out:
# {'A', 'B', 'C'}

# %%
len(set(data_stores["Store"]))
# Out:
# 45

# %%
len(data_stores)
# Out:
# 45

# %% [markdown]
# # Merge two tables (featues+sales)

# %%
data_merge=pd.merge(data_feature,data_sales,on="Date")

# %%
data_merge.head(100)
# Out:
#     Store_x      Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  5/2/2010        42.31       2.572        0.0        0.0
# 1         1  5/2/2010        42.31       2.572        0.0        0.0
# 2         1  5/2/2010        42.31       2.572        0.0        0.0
# 3         1  5/2/2010        42.31       2.572        0.0        0.0
# 4         1  5/2/2010        42.31       2.572        0.0        0.0
# 5         1  5/2/2010        42.31       2.572        0.0        0.0
# 6         1  5/2/2010        42.31       2.572        0.0        0.0
# 7         1  5/2/2010        42.31       2.572        0.0        0.0
# 8         1  5/2/2010        42.31       2.572        0.0        0.0
# 9         1  5/2/2010        42.31       2.572        0.0        0.0
# 10        1  5/2/2010        42.31       2.572        0.0        0.0
# 11        1  5/2/2010        42.31       2.572        0.0        0.0
# 12        1  5/2/2010        42.31       2.572        0.0        0.0
# ...

# %%
pd.Series.equals(data_merge['Store_x'],data_merge['Store_y'])
# Out:
# False

# %%
# checking if the  both holiday columns are equal or not
pd.Series.equals(data_merge['IsHoliday_x'],data_merge['IsHoliday_y'])
# Out:
# True

# %%
# as both holiday column are same drop one(cause redundant)
data_merge.drop(["IsHoliday_y"],axis=1)
# Out:
#           Store_x        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0               1    5/2/2010        42.31       2.572       0.00       0.00
# 1               1    5/2/2010        42.31       2.572       0.00       0.00
# 2               1    5/2/2010        42.31       2.572       0.00       0.00
# 3               1    5/2/2010        42.31       2.572       0.00       0.00
# 4               1    5/2/2010        42.31       2.572       0.00       0.00
# 5               1    5/2/2010        42.31       2.572       0.00       0.00
# 6               1    5/2/2010        42.31       2.572       0.00       0.00
# 7               1    5/2/2010        42.31       2.572       0.00       0.00
# 8               1    5/2/2010        42.31       2.572       0.00       0.00
# 9               1    5/2/2010        42.31       2.572       0.00       0.00
# 10              1    5/2/2010        42.31       2.572       0.00       0.00
# ...

# %%
data_merge[220:240]
# Out:
#      Store_x      Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 220        1  5/2/2010        42.31       2.572        0.0        0.0
# 221        1  5/2/2010        42.31       2.572        0.0        0.0
# 222        1  5/2/2010        42.31       2.572        0.0        0.0
# 223        1  5/2/2010        42.31       2.572        0.0        0.0
# 224        1  5/2/2010        42.31       2.572        0.0        0.0
# 225        1  5/2/2010        42.31       2.572        0.0        0.0
# 226        1  5/2/2010        42.31       2.572        0.0        0.0
# 227        1  5/2/2010        42.31       2.572        0.0        0.0
# 228        1  5/2/2010        42.31       2.572        0.0        0.0
# 229        1  5/2/2010        42.31       2.572        0.0        0.0
# 230        1  5/2/2010        42.31       2.572        0.0        0.0
# 231        1  5/2/2010        42.31       2.572        0.0        0.0
# ...
